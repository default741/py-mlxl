# %% [markdown]
# ### Importing Required Libraries

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import make_scorer, fbeta_score, roc_curve, precision_recall_curve
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE, ADASYN, KMeansSMOTE, SVMSMOTE, BorderlineSMOTE
from imblearn.under_sampling import TomekLinks, RepeatedEditedNearestNeighbours, NearMiss
from imblearn.combine import SMOTETomek, SMOTEENN

# from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
from tqdm import tqdm

import joblib
import itertools

import pandas as pd
import numpy as np

## Pycaret
from pycaret.classification import *

# %% [markdown]
# ### Loading the dataset after feature selection is done

# %%
def load_datasets(file_path: str) -> dict:
    """
    Load Feature Selected Datasets.

    Args:
        file_path (str): Path of saved Data

    Returns:
        dict: Feature Selected Data
    """
    return joblib.load(file_path)['meta_data']

# %% [markdown]
# ### Concatinating Train and Test datasets to get the original data since pycaret requires whole data to work on.

# %%
def get_full_data(data_dict: dict):
    X_train, X_test, y_train, y_test = data_dict['X_train'], data_dict['X_test'],data_dict['y_train'],data_dict['y_test']
    y_train = pd.DataFrame({'target_label': y_train})
    y_test = pd.DataFrame({'target_label': y_test})
    train = pd.concat([X_train, y_train],axis = 1)
    test = pd.concat([X_test, y_test], axis = 1)
    data = pd.concat([train,test])
    return data

# %% [markdown]
# ### Method that implements PyCaret steps and returns model_comparisions df.

# %%
def pycarat_modelling(data:pd.DataFrame,test_size:float,kpi_indicator:str, data_type: str):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    if data_type =='balanced':
        clf1 = setup(data, target = 'target_label', train_size= 1.0 - test_size, numeric_features = 
                 list(data.select_dtypes(include=numerics).columns)[:-1])
    else:
        clf1 = setup(data, target = 'target_label', train_size= 1.0 - test_size, numeric_features = 
                 list(data.select_dtypes(include=numerics).columns)[:-1], fix_imbalance = True)
    # Compare models
    compare_models(sort = kpi_indicator)

    df = pull()
    return df

# %% [markdown]
# ### Method to get the final models dataframe by iterating through each feature selection method.

# %%
def model_building(data_dict:dict, data:pd.DataFrame, test_size: float, kpi_indicator:str, data_type: str):
    fts = list(data_dict['selected_features'].keys())[:4]
    result = pd.DataFrame()
    for data_name in fts:
        print("--------------------- : ", data_name)
        for key,value in data_dict['selected_features'][data_name].items():
            print(key)
            if len(list(data_dict['selected_features'][data_name][key])) > 0:
                data_filtered = data[list(data_dict['selected_features'][data_name][key]) + ['target_label']]
                models_res = pycarat_modelling(data = data_filtered, test_size = test_size, kpi_indicator = kpi_indicator,
                                              data_type = data_type)
                models_res['feature_used'] = data_name+'_'+key
                result = pd.concat([result, models_res])
    result = result.sort_values(by = [kpi_indicator], ascending = False).reset_index(drop = True).iloc[:10, :]
    return result

# %% [markdown]
# ### Compile method that executes all required functions to get models list.

# %%
def compile_method(file_path:str, data_type: str, test_size: float,kpi_indicator:str):
    print("-------- loading data ----------------------------")
    data_dict = load_datasets(file_path=file_path)
    print("-------- loading data done -------------------")
    
    print("-------- Merging the data ---------------")
    data = get_full_data(data_dict)
    print(" ------- Data Merging done -------------------")

    print("--------- Modelling Starts ----------")
    fin_res = model_building(data_dict = data_dict, data = data, test_size = test_size, kpi_indicator = kpi_indicator,
                            data_type = data_type)
    print("-------- Modelling Ends  --------------")
    return fin_res

# %% [markdown]
# ### Config file

# %%
config = {
        'file_path' :'fin_feature_selected_data_v1.joblib',
        'data_type': 'balanced',
        'test_size': 0.2,
        'kpi_indicator': 'AUC'
    }

models = compile_method(**config)
# Out:
# <style type="text/css">
# #T_1593e th {
#   text-align: left;
# }
# #T_1593e_row0_col0, #T_1593e_row0_col1, #T_1593e_row0_col3, #T_1593e_row0_col4, #T_1593e_row0_col5, #T_1593e_row0_col6, #T_1593e_row0_col7, #T_1593e_row1_col0, #T_1593e_row1_col1, #T_1593e_row1_col2, #T_1593e_row1_col3, #T_1593e_row1_col4, #T_1593e_row1_col5, #T_1593e_row1_col6, #T_1593e_row1_col7, #T_1593e_row2_col0, #T_1593e_row2_col1, #T_1593e_row2_col2, #T_1593e_row2_col3, #T_1593e_row2_col5, #T_1593e_row3_col0, #T_1593e_row3_col1, #T_1593e_row3_col2, #T_1593e_row3_col3, #T_1593e_row3_col4, #T_1593e_row3_col5, #T_1593e_row3_col6, #T_1593e_row3_col7, #T_1593e_row4_col0, #T_1593e_row4_col1, #T_1593e_row4_col2, #T_1593e_row4_col3, #T_1593e_row4_col4, #T_1593e_row4_col5, #T_1593e_row4_col6, #T_1593e_row4_col7, #T_1593e_row5_col0, #T_1593e_row5_col1, #T_1593e_row5_col2, #T_1593e_row5_col3, #T_1593e_row5_col4, #T_1593e_row5_col5, #T_1593e_row5_col6, #T_1593e_row5_col7, #T_1593e_row6_col0, #T_1593e_row6_col1, #T_1593e_row6_col2, #T_1593e_row6_col3, #T_1593e_row6_col4, #T_1593e_row6_col5, #T_1593e_row6_col6, #T_1593e_row6_col7, #T_1593e_row7_col0, #T_1593e_row7_col1, #T_1593e_row7_col2, #T_1593e_row7_col3, #T_1593e_row7_col4, #T_1593e_row7_col5, #T_1593e_row7_col6, #T_1593e_row7_col7, #T_1593e_row8_col0, #T_1593e_row8_col1, #T_1593e_row8_col2, #T_1593e_row8_col3, #T_1593e_row8_col4, #T_1593e_row8_col5, #T_1593e_row8_col6, #T_1593e_row8_col7, #T_1593e_row9_col0, #T_1593e_row9_col1, #T_1593e_row9_col2, #T_1593e_row9_col3, #T_1593e_row9_col4, #T_1593e_row9_col5, #T_1593e_row9_col6, #T_1593e_row9_col7, #T_1593e_row10_col0, #T_1593e_row10_col1, #T_1593e_row10_col2, #T_1593e_row10_col4, #T_1593e_row10_col6, #T_1593e_row10_col7, #T_1593e_row11_col0, #T_1593e_row11_col2, #T_1593e_row11_col3, #T_1593e_row11_col4, #T_1593e_row11_col5, #T_1593e_row11_col6, #T_1593e_row11_col7, #T_1593e_row12_col0, #T_1593e_row12_col2, #T_1593e_row12_col3, #T_1593e_row12_col4, #T_1593e_row12_col5, #T_1593e_row12_col6, #T_1593e_row12_col7, #T_1593e_row13_col0, #T_1593e_row13_col1, #T_1593e_row13_col2, #T_1593e_row13_col3, #T_1593e_row13_col4, #T_1593e_row13_col5, #T_1593e_row13_col6, #T_1593e_row13_col7, #T_1593e_row14_col0, #T_1593e_row14_col2, #T_1593e_row14_col3, #T_1593e_row14_col4, #T_1593e_row14_col5, #T_1593e_row14_col6, #T_1593e_row14_col7 {
#   text-align: left;
# }
# #T_1593e_row0_col2, #T_1593e_row2_col4, #T_1593e_row2_col6, #T_1593e_row2_col7, #T_1593e_row10_col3, #T_1593e_row10_col5, #T_1593e_row11_col1, #T_1593e_row12_col1, #T_1593e_row14_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1593e_row0_col8, #T_1593e_row1_col8, #T_1593e_row2_col8, #T_1593e_row3_col8, #T_1593e_row4_col8, #T_1593e_row6_col8, #T_1593e_row7_col8, #T_1593e_row8_col8, #T_1593e_row9_col8, #T_1593e_row10_col8, #T_1593e_row11_col8, #T_1593e_row12_col8, #T_1593e_row13_col8, #T_1593e_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1593e_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1593e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1593e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1593e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1593e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1593e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1593e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1593e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1593e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1593e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1593e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1593e_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_1593e_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_1593e_row0_col1" class="data row0 col1" >0.5431</td>
#       <td id="T_1593e_row0_col2" class="data row0 col2" >0.5084</td>
#       <td id="T_1593e_row0_col3" class="data row0 col3" >0.2036</td>
#       <td id="T_1593e_row0_col4" class="data row0 col4" >0.4321</td>
#       <td id="T_1593e_row0_col5" class="data row0 col5" >0.2767</td>
#       <td id="T_1593e_row0_col6" class="data row0 col6" >0.0022</td>
#       <td id="T_1593e_row0_col7" class="data row0 col7" >0.0026</td>
#       <td id="T_1593e_row0_col8" class="data row0 col8" >0.5970</td>
#     </tr>
#     <tr>
#       <th id="T_1593e_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_1593e_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_1593e_row1_col1" class="data row1 col1" >0.5438</td>
#       <td id="T_1593e_row1_col2" class="data row1 col2" >0.5068</td>
#       <td id="T_1593e_row1_col3" class="data row1 col3" >0.2135</td>
#       <td id="T_1593e_row1_col4" class="data row1 col4" >0.4359</td>
#       <td id="T_1593e_row1_col5" class="data row1 col5" >0.2864</td>
#       <td id="T_1593e_row1_col6" class="data row1 col6" >0.0061</td>
#       <td id="T_1593e_row1_col7" class="data row1 col7" >0.0070</td>
#       <td id="T_1593e_row1_col8" class="data row1 col8" >0.4980</td>
#     </tr>
#     <tr>
#       <th id="T_1593e_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_1593e_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1593e_row2_col1" class="data row2 col1" >0.5569</td>
#       <td id="T_1593e_row2_col2" class="data row2 col2" >0.5042</td>
#       <td id="T_1593e_row2_col3" class="data row2 col3" >0.1339</td>
#       <td id="T_1593e_row2_col4" class="data row2 col4" >0.4469</td>
#       <td id="T_1593e_row2_col5" class="data row2 col5" >0.2060</td>
#       <td id="T_1593e_row2_col6" class="data row2 col6" >0.0097</td>
#       <td id="T_1593e_row2_col7" class="data row2 col7" >0.0134</td>
#       <td id="T_1593e_row2_col8" class="data row2 col8" >0.0770</td>
#     </tr>
#     <tr>
#       <th id="T_1593e_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_1593e_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_1593e_row3_col1" class="data row3 col1" >0.5359</td>
#       <td id="T_1593e_row3_col2" class="data row3 col2" >0.5030</td>
#       <td id="T_1593e_row3_col3" class="data row3 col3" >0.2397</td>
#       <td id="T_1593e_row3_col4" class="data row3 col4" >0.4276</td>
#       <td id="T_1593e_row3_col5" class="data row3 col5" >0.3070</td>
#       <td id="T_1593e_row3_col6" class="data row3 col6" >-0.0018</td>
#       <td id="T_1593e_row3_col7" class="data row3 col7" >-0.0019</td>
#       <td id="T_1593e_row3_col8" class="data row3 col8" >0.4100</td>
#     </tr>
#     <tr>
#       <th id="T_1593e_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_1593e_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_1593e_row4_col1" class="data row4 col1" >0.5261</td>
#       <td id="T_1593e_row4_col2" class="data row4 col2" >0.5017</td>
#       <td id="T_1593e_row4_col3" class="data row4 col3" >0.2989</td>
#       <td id="T_1593e_row4_col4" class="data row4 col4" >0.4259</td>
#       <td id="T_1593e_row4_col5" class="data row4 col5" >0.3512</td>
#       <td id="T_1593e_row4_col6" class="data row4 col6" >-0.0043</td>
#       <td id="T_1593e_row4_col7" class="data row4 col7" >-0.0044</td>
#       <td id="T_1593e_row4_col8" class="data row4 col8" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_1593e_level0_row5" class="row_heading level0 row5" >dummy</th>
#       <td id="T_1593e_row5_col0" class="data row5 col0" >Dummy Classifier</td>
#       <td id="T_1593e_row5_col1" class="data row5 col1" >0.5708</td>
#       <td id="T_1593e_row5_col2" class="data row5 col2" >0.5000</td>
#       <td id="T_1593e_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_1593e_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_

# %%
models
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0         Decision Tree Classifier    0.5362  0.5107  0.3029  0.4328  0.3562
# 1        Extreme Gradient Boosting    0.5477  0.5094  0.1949  0.4254  0.2671
# 2  Quadratic Discriminant Analysis    0.4415  0.5087  0.8953  0.3831  0.5365
# 3        Extreme Gradient Boosting    0.5538  0.5085  0.1501  0.4302  0.2224
# 4        Extreme Gradient Boosting    0.5431  0.5084  0.2036  0.4321  0.2767
# 5             Ada Boost Classifier    0.5743  0.5084  0.0197  0.4875  0.0378
# 6           Extra Trees Classifier    0.5408  0.5081  0.2562  0.4298  0.3209
# 7     Linear Discriminant Analysis    0.5745  0.5075  0.0003  0.1333  0.0006
# 8        Extreme Gradient Boosting    0.5562  0.5074  0.1787  0.4396  0.2539
# 9                      Naive Bayes    0.4816  0.5074  0.6323  0.4223  0.4819
#
#     Kappa     MCC  TT (Sec)                                       feature_used
# 0  0.0113  0.0117     0.038  mutual_info_classif_selection_mutual_info_classif
# 1  0.0017  0.0020     0.626           permutation_impt_selection_random_forest
# 2  0.0006  0.0057     0.015              anova_f_value_selection_anova_f_value
# 3  0.0030  0.0039     0.383              anova_f_value_selection_anova_f_value
# 4  0.0022  0.0026     0.597     permutation_impt_selection_logistic_regression
# 5  0.0053  0.0172     0.175              anova_f_value_selection_anova_f_value
# 6  0.0069  0.0072     0.365  mutual_info_classif_selection_mutual_info_classif
# 7 -0.0002 -0.0010     0.015              anova_f_value_selection_anova_f_value
# 8  0.0126  0.0152     0.548                              logit_selection_logit
# 9  0.0024  0.0022     0.008                permutation_impt_selection_catboost
