# %% [markdown]
# ### Importing Required Libraries

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      -------------------------------------- 100.3/100.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages (from scikit-optimize) (1.20.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages (from scikit-optimize) (1.2.0)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages (from scikit-optimize) (0.23.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages (from scikit-optimize) (1.5.4)
# Requirement already satisfied: PyYAML in c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages (from pyaml>=16.9->scikit-optimize) (5.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-21.10.1 scikit-optimize-0.9.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tammana karthik\anaconda3\envs\pycaret_env\lib\site-packages)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import make_scorer, fbeta_score, roc_curve, precision_recall_curve
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE, ADASYN, KMeansSMOTE, SVMSMOTE, BorderlineSMOTE
from imblearn.under_sampling import TomekLinks, RepeatedEditedNearestNeighbours, NearMiss
from imblearn.combine import SMOTETomek, SMOTEENN

# from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
from tqdm import tqdm

import joblib
import itertools

import pandas as pd
import numpy as np

## Pycaret
from pycaret.classification import *

# %% [markdown]
# ### Loading the dataset after feature selection is done

# %%
def load_datasets(file_path: str) -> dict:
    """
    Load Feature Selected Datasets.

    Args:
        file_path (str): Path of saved Data

    Returns:
        dict: Feature Selected Data
    """
    return joblib.load(file_path)['meta_data']

# %% [markdown]
# ### Concatinating Train and Test datasets to get the original data since pycaret requires whole data to work on.

# %%
def get_full_data(data_dict: dict) -> pd.DataFrame:
    """
    Merges Train and Test data into a single dataframe.
    
    Args:
        data_dict (dict) : loaded data dictionary.
        
    Returns:
        pd.DataFrame : Merged DataFrame.
    """
    X_train, X_test, y_train, y_test = data_dict['X_train'], data_dict['X_test'],data_dict['y_train'],data_dict['y_test']
    y_train = pd.DataFrame({'target_label': y_train})
    y_test = pd.DataFrame({'target_label': y_test})
    train = pd.concat([X_train, y_train],axis = 1)
    test = pd.concat([X_test, y_test], axis = 1)
    data = pd.concat([train,test])
    return data

# %% [markdown]
# ### Method that implements PyCaret steps and returns model_comparisions df and best model.

# %%
def pycarat_modelling(data:pd.DataFrame,test_size:float,kpi_indicator:str, data_type: str):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    if data_type =='balanced':
        clf1 = setup(data, target = 'target_label', train_size= 1.0 - test_size, numeric_features = 
                 list(data.select_dtypes(include=numerics).columns)[:-1], html = False)
    else:
        clf1 = setup(data, target = 'target_label', train_size= 1.0 - test_size, numeric_features = 
                 list(data.select_dtypes(include=numerics).columns)[:-1], fix_imbalance = True, html = False)
    # Compare models
    best_model = compare_models(sort = kpi_indicator)

    df = pull()
    return best_model, df

# %% [markdown]
# ### Method to implement HyperParameter tuning using Bayesian optimization technique.

# %%
def hyperparam_tuning(best_model:object, kpi_indicator:str):
    model_tuned  = tune_model(best_model, search_library = 'scikit-optimize',optimize = kpi_indicator)
    return model_tuned

# %% [markdown]
# ### Method to get the final models dictionary by iterating through each feature selection method along with hyperparameter tuning.

# %%
def model_building_tuning(data_dict:dict, data:pd.DataFrame, test_size: float, kpi_indicator:str, data_type: str):
    fts = list(data_dict['selected_features'].keys())[3:5]
    li = []
    al_dict = {}
    for data_name in fts:
        data_name_dict = {}
        print("--------------------- : ", data_name)
        for key,value in data_dict['selected_features'][data_name].items():
            print(key)
            if len(list(data_dict['selected_features'][data_name][key])) > 0:
                data_filtered = data[list(data_dict['selected_features'][data_name][key]) + ['target_label']]
                best_model,df = pycarat_modelling(data = data_filtered, test_size = test_size, kpi_indicator = kpi_indicator,
                                              data_type = data_type)
                tuned_model = hyperparam_tuning(best_model, kpi_indicator)
                #data_name_dict[data_name+'_'+key] = tuned_model
                data_name_dict[key] = tuned_model
        al_dict[data_name] = data_name_dict
        #li.append(data_name_dict)
    return al_dict

# %% [markdown]
# ### Method to get the final models dataframe by iterating through each feature selection method.

# %%
def model_building(data_dict:dict, data:pd.DataFrame, test_size: float, kpi_indicator:str, data_type: str):
    fts = list(data_dict['selected_features'].keys())[0:1]
    result = pd.DataFrame()
    for data_name in fts:
        print("--------------------- : ", data_name)
        for key,value in data_dict['selected_features'][data_name].items():
            print(key)
            if len(list(data_dict['selected_features'][data_name][key])) > 0:
                data_filtered = data[list(data_dict['selected_features'][data_name][key]) + ['target_label']]
                best_model,models_res = pycarat_modelling(data = data_filtered, test_size = test_size, kpi_indicator = kpi_indicator,
                                              data_type = data_type)
                models_res['feature_used'] = data_name+'-'+key
                result = pd.concat([result, models_res])
    result = result.sort_values(by = [kpi_indicator], ascending = False).reset_index(drop = True).iloc[:10, :]
    return result

# %% [markdown]
# ### Tuning only top 10 feature selection methods from the model comparision results.

# %%
def top_10_tuning(data:pd.DataFrame, test_size: float, kpi_indicator:str, data_type: str, res_df: pd.DataFrame):
    features_used = list(res_df['feature_used'].unique())
    tuned_dict = {}
    for ft_used in features_used:
        method_name, sub_method_name = ft_used.split('-')
        data_filtered = data[list(data_dict['selected_features'][method_name][sub_method_name]) + ['target_label']]
        best_model,models_res = pycarat_modelling(data = data_filtered, test_size = test_size, kpi_indicator = kpi_indicator,
                                              data_type = data_type)
        tuned_model = hyperparam_tuning(best_model, kpi_indicator)
        tuned_dict[method_name+':'+sub_method_name] = tuned_model
    return tuned_dict

# %% [markdown]
# ### Compile method that executes all required functions to get models list.

# %%
def compile_method(file_path : str,data_type : str,test_size : float,kpi_indicator : str,with_tuning : bool):
    print("-------- loading data ----------------------------")
    data_dict = load_datasets(file_path=file_path)
    print("-------- loading data done -------------------")
    
    print("-------- Merging the data ---------------")
    data = get_full_data(data_dict)
    print(" ------- Data Merging done -------------------")

    print("--------- Modelling Starts ----------")
    if with_tuning:
        fin_res = model_building_tuning(data_dict = data_dict, data = data, test_size = test_size, kpi_indicator = kpi_indicator,
                                data_type = data_type)
    else:
        res = model_building(data_dict = data_dict, data = data, test_size = test_size, kpi_indicator = kpi_indicator,
                                data_type = data_type)
        
        print("RESULT ______________________")
        print(res)
        fin_res = top_10_tuning(data = data, test_size = test_size, kpi_indicator = kpi_indicator,
                                data_type = data_type, res_df = res)
    print("-------- Modelling Ends  --------------")
    return fin_res

# %% [markdown]
# ### Config file

# %%
config = {
        'file_path' :'fin_feature_selected_data_v1.joblib',
        'data_type': 'balanced',
        'test_size': 0.2,
        'kpi_indicator': 'AUC',
        'with_tuning': False
    }

models = compile_method(**config)
# Out:
# -------- loading data ----------------------------
# -------- loading data done -------------------
# -------- Merging the data ---------------
#  ------- Data Merging done -------------------
# --------- Modelling Starts ----------
# fts -  ['anova_f_value_selection']
# --------------------- :  anova_f_value_selection
# anova_f_value
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                     Data Type
# topcoat color_BK05    Numeric
# Basecoat Humidity     Numeric
# topcoat color_BK08    Numeric
# topcoat color_BK06    Numeric
# primer color_MK05     Numeric
# primer color_MK04     Numeric
# topcoat color_BK34    Numeric
# topcoat color_BK33    Numeric
# primer color_PK02     Numeric
# topcoat color_BK25    Numeric
# Ambient Temperature   Numeric
# target_label            Label
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 9
#       1 config = {
#       2         'file_path' :'fin_feature_selected_data_v1.joblib',
#       3         'data_type': 'balanced',
#    (...)
#       6         'with_tuning': False
#       7     }
# ----> 9 models = compile_method(**config)
#
# Cell In[107], line 15, in compile_method(file_path, data_type, test_size, kpi_indicator, with_tuning)
#      12     fin_res = model_building_tuning(data_dict = data_dict, data = data, test_size = test_size, kpi_indicator = kpi_indicator,
#      13                             data_type = data_type)
#      14 else:
# ---> 15     res = model_building(data_dict = data_dict, data = data, test_size = test_size, kpi_indicator = kpi_indicator,
#      16                             data_type = data_type)
#      18     print("RESULT ______________________")
#      19     print(res)
#
# Cell In[105], line 11, in model_building(data_dict, data, test_size, kpi_indicator, data_type)
#       9 if len(list(data_dict['selected_features'][data_name][key])) > 0:
#      10     data_filtered = data[list(data_dict['selected_features'][data_name][key]) + ['target_label']]
# ---> 11     best_model,models_res = pycarat_modelling(data = data_filtered, test_size = test_size, kpi_indicator = kpi_indicator,
#      12                                   data_type = data_type)
#      13     models_res['feature_used'] = data_name+':'+key
#      14     result = pd.concat([result, models_res])
#
# Cell In[100], line 4, in pycarat_modelling(data, test_size, kpi_indicator, data_type)
#       2 numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
#       3 if data_type =='balanced':
# ----> 4     clf1 = setup(data, target = 'target_label', train_size= 1.0 - test_size, numeric_features =
#       5              list(data.select_dtypes(include=numerics).columns)[:-1], html = False)
#       6 else:
#       7     clf1 = setup(data, target = 'target_label', train_size= 1.0 - test_size, numeric_features =
#       8              list(data.select_dtypes(include=numerics).columns)[:-1], fix_imbalance = True, html = False)
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\pycaret\classification.py:599, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     596 if log_plots == True:
#     597     log_plots = ["auc", "confusion_matrix", "feature"]
# --> 599 return pycaret.internal.tabular.setup(
#     600     ml_usecase="classification",
#     601     available_plots=available_plots,
#     602     data=data,
#     603     target=target,
#     604     train_size=train_size,
#     605     test_data=test_data,
#     606     preprocess=preprocess,
#     607     imputation_type=imputation_type,
#     608     iterative_imputation_iters=iterative_imputation_iters,
#     609     categorical_features=categorical_features,
#     610     categorical_imputation=categorical_imputation,
#     611     categorical_iterative_imputer=categorical_iterative_imputer,
#     612     ordinal_features=ordinal_features,
#     613     high_cardinality_features=high_cardinality_features,
#     614     high_cardinality_method=high_cardinality_method,
#     615     numeric_features=numeric_features,
#     616     numeric_imputation=numeric_imputation,
#     617     numeric_iterative_imputer=numeric_iterative_imputer,
#     618     date_features=date_features,
#     619     ignore_features=ignore_features,
#     620     normalize=normalize,
#     621     normalize_method=normalize_method,
#     622     transformation=transformation,
#     623     transformation_method=transformation_method,
#     624     handle_unknown_categorical=handle_unknown_categorical,
#     625     unknown_categorical_method=unknown_categorical_method,
#     626     pca=pca,
#     627     pca_method=pca_method,
#     628     pca_components=pca_components,
#     629     ignore_low_variance=ignore_low_variance,
#     630     combine_rare_levels=combine_rare_levels,
#     631     rare_level_threshold=rare_level_threshold,
#     632     bin_numeric_features=bin_numeric_features,
#     633     remove_outliers=remove_outliers,
#     634     outliers_threshold=outliers_threshold,
#     635     remove_multicollinearity=remove_multicollinearity,
#     636     multicollinearity_threshold=multicollinearity_threshold,
#     637     remove_perfect_collinearity=remove_perfect_collinearity,
#     638     create_clusters=create_clusters,
#     639     cluster_iter=cluster_iter,
#     640     polynomial_features=polynomial_features,
#     641     polynomial_degree=polynomial_degree,
#     642     trigonometry_features=trigonometry_features,
#     643     polynomial_threshold=polynomial_threshold,
#     644     group_features=group_features,
#     645     group_names=group_names,
#     646     feature_selection=feature_selection,
#     647     feature_selection_threshold=feature_selection_threshold,
#     648     feature_selection_method=feature_selection_method,
#     649     feature_interaction=feature_interaction,
#     650     feature_ratio=feature_ratio,
#     651     interaction_threshold=interaction_threshold,
#     652     fix_imbalance=fix_imbalance,
#     653     fix_imbalance_method=fix_imbalance_method,
#     654     data_split_shuffle=data_split_shuffle,
#     655     data_split_stratify=data_split_stratify,
#     656     fold_strategy=fold_strategy,
#     657     fold=fold,
#     658     fold_shuffle=fold_shuffle,
#     659     fold_groups=fold_groups,
#     660     n_jobs=n_jobs,
#     661     use_gpu=use_gpu,
#     662     custom_pipeline=custom_pipeline,
#     663     html=html,
#     664     session_id=session_id,
#     665     log_experiment=log_experiment,
#     666     experiment_name=experiment_name,
#     667     experiment_custom_tags=experiment_custom_tags,
#     668     log_plots=log_plots,
#     669     log_profile=log_profile,
#     670     log_data=log_data,
#     671     silent=silent,
#     672     verbose=verbose,
#     673     profile=profile,
#     674     profile_kwargs=profile_kwargs,
#     675 )
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\pycaret\internal\tabular.py:1408, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1405     train_data = pd.concat([X_train, y_train], axis=1)
#    1406     test_data = pd.concat([X_test, y_test], axis=1)
# -> 1408 train_data = prep_pipe.fit_transform(train_data)
#    1409 # workaround to also transform target
#    1410 dtypes.final_training_columns.append(target)
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\sklearn\pipeline.py:367, in Pipeline.fit_transform(self, X, y, **fit_params)
#     340 """Fit the model and transform with the final estimator
#     341
#     342 Fits all the transforms one after the other and transforms the
#    (...)
#     364     Transformed samples
#     365 """
#     366 fit_params_steps = self._check_fit_params(**fit_params)
# --> 367 Xt = self._fit(X, y, **fit_params_steps)
#     369 last_step = self._final_estimator
#     370 with _print_elapsed_time('Pipeline',
#     371                          self._log_message(len(self.steps) - 1)):
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\sklearn\pipeline.py:292, in Pipeline._fit(self, X, y, **fit_params_steps)
#     290     cloned_transformer = clone(transformer)
#     291 # Fit or load from cache the current transformer
# --> 292 X, fitted_transformer = fit_transform_one_cached(
#     293     cloned_transformer, X, y, None,
#     294     message_clsname='Pipeline',
#     295     message=self._log_message(step_idx),
#     296     **fit_params_steps[name])
#     297 # Replace the transformer of the step with the fitted
#     298 # transformer. This is necessary when loading the transformer
#     299 # from the cache.
#     300 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\sklearn\pipeline.py:740, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738 with _print_elapsed_time(message_clsname, message):
#     739     if hasattr(transformer, 'fit_transform'):
# --> 740         res = transformer.fit_transform(X, y, **fit_params)
#     741     else:
#     742         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\pycaret\internal\preprocess.py:421, in DataTypes_Auto_infer.fit_transform(self, dataset, y)
#     418 data = dataset
#     420 # since this is for training , we dont nees any transformation since it has already been transformed in fit
# --> 421 data = self.fit(data)
#     423 # additionally we just need to treat the target variable
#     424 # for ml use ase
#     425 if (self.ml_usecase == "classification") & (
#     426     data[self.target].dtype == "object"
#     427 ):
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\pycaret\internal\preprocess.py:323, in DataTypes_Auto_infer.fit(self, dataset, y)
#     320 dt_print_out.drop(index="dummy_target", errors="ignore", inplace=True)
#     322 display(dt_print_out[["Data Type"]])
# --> 323 self.response = input()
#     325 if self.response in [
#     326     "quit",
#     327     "Quit",
#    (...)
#     335     "Exit",
#     336 ]:
#     337     sys.exit(
#     338         "Read the documentation of setup to learn how to overwrite data types over the inferred types. setup function must run again before you continue modeling."
#     339     )
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~\anaconda3\envs\pycaret_env\lib\site-packages\ipykernel\kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
#    1216     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217     raise KeyboardInterrupt("Interrupted by user") from None
#    1218 except Exception:
#    1219     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
models ## taking top 10 and tuning them.
# Out:
# {'anova_f_value_selection:anova_f_value': ExtraTreesClassifier(bootstrap=True, ccp_alpha=0.0,
#                       class_weight='balanced_subsample', criterion='entropy',
#                       max_depth=3, max_features=0.46202644076613025,
#                       max_leaf_nodes=None, max_samples=None,
#                       min_impurity_decrease=2.0738458306192575e-05,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=9, min_weight_fraction_leaf=0.0,
#                       n_estimators=55, n_jobs=-1, oob_score=False,
#                       random_state=7444, verbose=0, warm_start=False),
#  'logit_selection:logit': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='manhattan',
#                       metric_params=None, n_jobs=-1, n_neighbors=45, p=2,
#                       weights='uniform')}

# %%
models ## tuning for all combinations of methods and sub methods.
# Out:
# {'permutation_impt_selection': {'random_forest': GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                              learning_rate=0.012401549537023198, loss='deviance',
#                              max_depth=6, max_features=0.6256381592381297,
#                              max_leaf_nodes=None,
#                              min_impurity_decrease=0.00034065548673317605,
#                              min_impurity_split=None, min_samples_leaf=5,
#                              min_samples_split=6, min_weight_fraction_leaf=0.0,
#                              n_estimators=134, n_iter_no_change=None,
#                              presort='deprecated', random_state=7134,
#                              subsample=0.7515343192991089, tol=0.0001,
#                              validation_fraction=0.1, verbose=0,
#                              warm_start=False),
#   'catboost': AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                      learning_rate=3.5714920770950163e-06, n_estimators=31,
#                      random_state=5897),
#   'xgboost': LGBMClassifier(bagging_fraction=0.9848611974761182, bagging_freq=4,
#                  boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                  feature_fraction=0.6798280426641321, importance_type='split',
#                  learning_rate=0.37185593692051394, max_depth=-1,
#                  min_child_samples=99, min_child_weight=0.001,
#                  min_split_gain=0.5749914692958749, n_estimators=82, n_jobs=-1,
#                  num_leaves=6, objective=None, random_state=2330,
#                  reg_alpha=4.8121658547798725e-09,
#                  reg_lambda=0.002214881840765291, silent='warn', subsample=1.0,
#                  subsample_for_bin=200000, subsample_freq=0),
#   'lightgbm': LGBMClassifier(bagging_fraction=0.8300834299174931, bagging_freq=7,
#                  boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                  feature_fraction=0.7319325528212907, importance_type='split',
#                  learning_rate=9.652459549443153e-05, max_depth=-1,
#                  min_child_samples=71, min_child_weight=0.001,
#                  min_split_gain=0.6872871079407797, n_estimators=178, n_jobs=-1,
#                  num_leaves=131, objective=None, random_state=1656,
#                  reg_alpha=3.326828759054149e-05,
#                  reg_lambda=2.0975277998616412e-07, silent='warn', subsample=1.0,
#                  subsample_for_bin=200000, subsample_freq=0),
#   'gradient_boosting': LGBMClassifier(bagging_fraction=0.7903635295801482, bagging_freq=6,
#                  boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                  feature_fraction=0.7469101318261426, importance_type='split',
#                  learning_rate=5.781453488473466e-06, max_depth=-1,
#                  min_child_samples=23, min_child_weight=0.001,
#                  min_split_gain=0.31242335152970774, n_estimators=82, n_jobs=-1,
#                  num_leaves=76, objective=None, random_state=7613,
#                  reg_alpha=0.021508648273130544,
#                  reg_lambda=0.00013470158591531457, silent='warn', subsample=1.0,
#                  subsample_for_bin=200000, subsample_freq=0),
#   'logistic_regression': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                          max_depth=3, max_features=0.7882063395459227,
#                          max_leaf_nodes=None,
#                          min_impurity_decrease=3.537802295526947e-05,
#                          min_impurity_split=None, min_samples_leaf=3,
#                          min_samples_split=3, min_weight_fraction_leaf=0.0,
#                          presort='deprecated', random_state=6299,
#                          splitter='best')},
#  'recursive_feature_elimination': {'random_forest': RandomForestClassifier(bootstrap=False, ccp_alpha=0.0,
#                          class_weight='balanced_subsample', criterion='gini',
#                          max_depth=5, max_features=0.79701954153819,
#                          max_leaf_nodes=None, max_samples=None,
#                          min_impurity_decrease=1.874492896316983e-09,
#                          min_impurity_split=None, min_samples_leaf=3,
#                          min_samples_split=8, min_weight_fraction_leaf=0.0,
#                          n_estimators=209, n_jobs=-1, oob_score=False,
#                          random_state=8588, verbose=0, warm_start=False),
#   'catboost': GaussianNB(priors=None, var_smoothing=0.2973778320995492),
#   'xgboost': GaussianNB(priors=None, var_smoothing=0.05847730760283778),
#   'lightgbm': XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=0.9926899271895304, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=0.055833221760840254,
#                 max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=9, max_leaves=None,
#                 min_child_weight=3, missing=nan, monotone_constraints=None,
#                 n_estimators=268, n_jobs=-1, num_parallel_tree=None,
#                 objective='binary:logistic', predictor=None, ...),
#   'gradient_boosting': GaussianNB(priors=None, var_smoothing=0.00011614660760722133),
#   'logistic_regression': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                          class_weight='balanced_subsample', criterion='gini',
#                          max_depth=9, max_features=0.6147043651919706,
#                          max_leaf_nodes=None, max_samples=None,
#                          min_impurity_decrease=4.555701440323541e-05,
#                          min_impurity_split=None, min_samples_leaf=4,
#                          min_samples_split=6, min_weight_fraction_leaf=0.0,
#                          n_estimators=293, n_jobs=-1, oob_score=False,
#                          random_state=4264, verbose=0, warm_start=False)}}

# %%
########### TESTING

# %%
t_knn = create_model(list(models.values())[1])
# Out:
# <style type="text/css">
# #T_3a7c0_row10_col0, #T_3a7c0_row10_col1, #T_3a7c0_row10_col2, #T_3a7c0_row10_col3, #T_3a7c0_row10_col4, #T_3a7c0_row10_col5, #T_3a7c0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3a7c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a7c0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3a7c0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3a7c0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3a7c0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3a7c0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3a7c0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3a7c0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a7c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a7c0_row0_col0" class="data row0 col0" >0.5652</td>
#       <td id="T_3a7c0_row0_col1" class="data row0 col1" >0.5012</td>
#       <td id="T_3a7c0_row0_col2" class="data row0 col2" >0.1140</td>
#       <td id="T_3a7c0_row0_col3" class="data row0 col3" >0.4514</td>
#       <td id="T_3a7c0_row0_col4" class="data row0 col4" >0.1821</td>
#       <td id="T_3a7c0_row0_col5" class="data row0 col5" >0.0131</td>
#       <td id="T_3a7c0_row0_col6" class="data row0 col6" >0.0189</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a7c0_row1_col0" class="data row1 col0" >0.5637</td>
#       <td id="T_3a7c0_row1_col1" class="data row1 col1" >0.4878</td>
#       <td id="T_3a7c0_row1_col2" class="data row1 col2" >0.0772</td>
#       <td id="T_3a7c0_row1_col3" class="data row1 col3" >0.4231</td>
#       <td id="T_3a7c0_row1_col4" class="data row1 col4" >0.1306</td>
#       <td id="T_3a7c0_row1_col5" class="data row1 col5" >-0.0005</td>
#       <td id="T_3a7c0_row1_col6" class="data row1 col6" >-0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a7c0_row2_col0" class="data row2 col0" >0.5700</td>
#       <td id="T_3a7c0_row2_col1" class="data row2 col1" >0.5266</td>
#       <td id="T_3a7c0_row2_col2" class="data row2 col2" >0.1054</td>
#       <td id="T_3a7c0_row2_col3" class="data row2 col3" >0.4688</td>
#       <td id="T_3a7c0_row2_col4" class="data row2 col4" >0.1722</td>
#       <td id="T_3a7c0_row2_col5" class="data row2 col5" >0.0195</td>
#       <td id="T_3a7c0_row2_col6" class="data row2 col6" >0.0294</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a7c0_row3_col0" class="data row3 col0" >0.5641</td>
#       <td id="T_3a7c0_row3_col1" class="data row3 col1" >0.5125</td>
#       <td id="T_3a7c0_row3_col2" class="data row3 col2" >0.1160</td>
#       <td id="T_3a7c0_row3_col3" class="data row3 col3" >0.4459</td>
#       <td id="T_3a7c0_row3_col4" class="data row3 col4" >0.1841</td>
#       <td id="T_3a7c0_row3_col5" class="data row3 col5" >0.0110</td>
#       <td id="T_3a7c0_row3_col6" class="data row3 col6" >0.0156</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a7c0_row4_col0" class="data row4 col0" >0.5529</td>
#       <td id="T_3a7c0_row4_col1" class="data row4 col1" >0.5102</td>
#       <td id="T_3a7c0_row4_col2" class="data row4 col2" >0.0931</td>
#       <td id="T_3a7c0_row4_col3" class="data row4 col3" >0.3869</td>
#       <td id="T_3a7c0_row4_col4" class="data row4 col4" >0.1501</td>
#       <td id="T_3a7c0_row4_col5" class="data row4 col5" >-0.0172</td>
#       <td id="T_3a7c0_row4_col6" class="data row4 col6" >-0.0253</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3a7c0_row5_col0" class="data row5 col0" >0.5156</td>
#       <td id="T_3a7c0_row5_col1" class="data row5 col1" >0.4864</td>
#       <td id="T_3a7c0_row5_col2" class="data row5 col2" >0.4341</td>
#       <td id="T_3a7c0_row5_col3" class="data row5 col3" >0.4296</td>
#       <td id="T_3a7c0_row5_col4" class="data row5 col4" >0.4318</td>
#       <td id="T_3a7c0_row5_col5" class="data row5 col5" >0.0098</td>
#       <td id="T_3a7c0_row5_col6" class="data row5 col6" >0.0098</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3a7c0_row6_col0" class="data row6 col0" >0.5037</td>
#       <td id="T_3a7c0_row6_col1" class="data row6 col1" >0.4948</td>
#       <td id="T_3a7c0_row6_col2" class="data row6 col2" >0.4306</td>
#       <td id="T_3a7c0_row6_col3" class="data row6 col3" >0.4174</td>
#       <td id="T_3a7c0_row6_col4" class="data row6 col4" >0.4239</td>
#       <td id="T_3a7c0_row6_col5" class="data row6 col5" >-0.0118</td>
#       <td id="T_3a7c0_row6_col6" class="data row6 col6" >-0.0118</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3a7c0_row7_col0" class="data row7 col0" >0.5075</td>
#       <td id="T_3a7c0_row7_col1" class="data row7 col1" >0.5057</td>
#       <td id="T_3a7c0_row7_col2" class="data row7 col2" >0.4218</td>
#       <td id="T_3a7c0_row7_col3" class="data row7 col3" >0.4196</td>
#       <td id="T_3a7c0_row7_col4" class="data row7 col4" >0.4207</td>
#       <td id="T_3a7c0_row7_col5" class="data row7 col5" >-0.0077</td>
#       <td id="T_3a7c0_row7_col6" class="data row7 col6" >-0.0077</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3a7c0_row8_col0" class="data row8 col0" >0.5082</td>
#       <td id="T_3a7c0_row8_col1" class="data row8 col1" >0.5068</td>
#       <td id="T_3a7c0_row8_col2" class="data row8 col2" >0.4148</td>
#       <td id="T_3a7c0_row8_col3" class="data row8 col3" >0.4192</td>
#       <td id="T_3a7c0_row8_col4" class="data row8 col4" >0.4170</td>
#       <td id="T_3a7c0_row8_col5" class="data row8 col5" >-0.0083</td>
#       <td id="T_3a7c0_row8_col6" class="data row8 col6" >-0.0083</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3a7c0_row9_col0" class="data row9 col0" >0.5328</td>
#       <td id="T_3a7c0_row9_col1" class="data row9 col1" >0.5219</td>
#       <td id="T_3a7c0_row9_col2" class="data row9 col2" >0.4482</td>
#       <td id="T_3a7c0_row9_col3" class="data row9 col3" >0.4489</td>
#       <td id="T_3a7c0_row9_col4" class="data row9 col4" >0.4485</td>
#       <td id="T_3a7c0_row9_col5" class="data row9 col5" >0.0432</td>
#       <td id="T_3a7c0_row9_col6" class="data row9 col6" >0.0432</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3a7c0_row10_col0" class="data row10 col0" >0.5384</td>
#       <td id="T_3a7c0_row10_col1" class="data row10 col1" >0.5054</td>
#       <td id="T_3a7c0_row10_col2" class="data row10 col2" >0.2655</td>
#       <td id="T_3a7c0_row10_col3" class="data row10 col3" >0.4311</td>
#       <td id="T_3a7c0_row10_col4" class="data row10 col4" >0.2961</td>
#       <td id="T_3a7c0_row10_col5" class="data row10 col5" >0.0051</td>
#       <td id="T_3a7c0_row10_col6" class="data row10 col6" >0.0063</td>
#     </tr>
#     <tr>
#       <th id="T_3a7c0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3a7c0_row11_col0" class="data row11 col0" >0.0262</td>
#       <td id="T_3a7c0_row11_col1" class="data row11 col1" >0.0126</td>
#       <td id="T_3a7c0_row11_col2" class="data row11 col2" >0.1649</td>
#       <td id="T_3a7c0_row11_col3" class="data row11 col3" >0.0220</td>
#       <td id="T_3a7c0_

# %%
predict_model(t_knn)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c499">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c499_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8c499_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8c499_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8c499_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8c499_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8c499_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8c499_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8c499_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c499_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c499_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_8c499_row0_col1" class="data row0 col1" >0.5624</td>
#       <td id="T_8c499_row0_col2" class="data row0 col2" >0.5065</td>
#       <td id="T_8c499_row0_col3" class="data row0 col3" >0.1013</td>
#       <td id="T_8c499_row0_col4" class="data row0 col4" >0.4431</td>
#       <td id="T_8c499_row0_col5" class="data row0 col5" >0.1648</td>
#       <td id="T_8c499_row0_col6" class="data row0 col6" >0.0073</td>
#       <td id="T_8c499_row0_col7" class="data row0 col7" >0.0110</td>
#     </tr>
#   </tbody>
# </table>
#       Topcoat Last Used  Ambient Humidity  Ambient Temperature  \
# 0              1.719010         -0.257420            -0.429320
# 1             -0.019485         -0.084228            -0.057762
# 2             -0.019485         -0.084228            -0.057762
# 3             -0.449960          1.063220            -0.188720
# 4             -0.449960          0.837770            -1.947700
# ...                 ...               ...                  ...
# 5761          -0.019485         -0.084228            -0.057762
# 5762           2.471650          0.694550             0.064900
# 5763          -0.536700          1.171210            -0.233410
# 5764          -0.186200          0.811470            -1.935630
# 5765          -0.449960          1.327610            -0.650890
#
#       Paint Temperature  Paint Pressure  Electrical Resistivity  \
# 0               0.41436       -0.331800                2.660760
# 1               0.21326       -0.331063                0.078066
# 2               0.21326       -0.331063                0.078066
# 3              -1.30537       -0.379550               -1.063070
# 4              -1.81854       -0.702570                1.943380
# ...                 ...             ...                     ...
# 5761            0.21326       -0.331063                0.078066
# 5762           -1.19519       -0.241770               -0.914350
# 5763           -0.08177       -0.458590               -0.712440
# 5764           -1.46584        0.906410                1.818950
# 5765           -0.96699       -0.267340               -0.635660
#
#       Paint Viscosity  Basecoat Humidity  Basecoat Temperature  \
# 0            0.740700          -0.649690             -0.139610
# 1            0.066668           0.237685             -0.091914
# 2            0.066668           0.237685             -0.091914
# 3            1.574000           0.883700             -0.000530
# 4           -0.546910           0.662270             -0.653920
# ...               ...                ...                   ...
# 5761         0.066668           0.237685             -0.091914
# 5762         1.033520           0.780090             -0.000530
# 5763        -0.491920           0.811920              0.134360
# 5764        -1.086700           0.679220             -0.631170
# 5765         0.284240           0.762670             -0.697440
#
#       Clearcoat Humidity  ...  topcoat color_BK16  topcoat color_BK21  \
# 0              -0.233200  ...           -0.774400           -0.048240
# 1               0.020019  ...           -0.020119           -0.000323
# 2               0.020019  ...           -0.020119           -0.000323
# 3              -0.144340  ...            1.291310           -0.048240
# 4               0.203030  ...            1.291310           -0.048240
# ...                  ...  ...                 ...                 ...
# 5761            0.020019  ...           -0.020119           -0.000323
# 5762           -1.500810  ...           -0.774400           -0.048240
# 5763            1.455780  ...            1.291310           -0.048240
# 5764            0.293720  ...           -0.774400           -0.048240
# 5765           -0.524140  ...            1.291310           -0.048240
#
#       topcoat color_BK25  topcoat color_BK26  topcoat color_BK32  \
# 0              -0.022720           -0.085600           -0.047700
# 1              -0.017884           -0.001604           -0.013088
# 2              -0.017884           -0.001604           -0.013088
# 3              -0.022720           -0.085600           -0.047700
# 4              -0.022720           -0.085600           -0.047700
# ...                  ...                 ...                 ...
# 5761           -0.017884           -0.001604           -0.013088
# 5762           -0.022720           -0.085600           -0.047700
# 5763           -0.022720           -0.085600           -0.047700
# 5764           -0.022720           -0.085600           -0.047700
# 5765           -0.022720           -0.085600           -0.047700
#
#       topcoat color_BK33  topcoat color_BK34  target_label  Label   Score
# 0              -0.034470           -0.060640           0.0    0.0  0.5778
# 1               0.013377            0.019342           0.0    0.0  0.6000
# 2               0.013377            0.019342           1.0    0.0  0.6000
# 3              -0.034470           -0.060640           1.0    0.0  0.6000
# 4              -0.034470           -0.060640           0.0    0.0  0.6000
# ...                  ...                 ...           ...    ...     ...
# 5761            0.013377            0.019342           1.0    0.0  0.6000
# 5762           -0.034470           -0.060640           0.0    0.0  0.5111
# 5763           -0.034470           -0.060640           1.0    0.0  0.6889
# 5764           -0.034470           -0.060640           0.0    0.0  0.5778
# 5765           -0.034470           -0.060640           1.0    0.0  0.6222
#
# [5766 rows x 44 columns]

# %%
# data_dict = load_datasets(file_path='fin_feature_selected_data_v1.joblib')
# data = get_full_data(data_dict)
# numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
# setup(data, target = 'target_label', train_size= 0.7, numeric_features = 
#                  list(data.select_dtypes(include=numerics).columns)[:-1])
# best_model = compare_models(sort = 'AUC')
# best_model


# td = tune_model(top_1)
# td

# %%
# model_tuned = tune_model(estimator = best_model,search_library = 'scikit-optimize', n_iter = 2, optimize = 'AUC')
# model_tuned

# %%
#plot_model(model_tuned, plot = 'class_report')

# %%
#predict_model(model_tuned)
